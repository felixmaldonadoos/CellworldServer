# %% [markdown]
# ### Pavlok delay times

# %%
import numpy as np
times = np.array([
    0.21893072128295898, 0.2693202495574951, 0.22445321083068848, 0.25324344635009766,
    0.25000786781311035, 0.29961442947387695, 0.3061208724975586, 0.28900671005249023,
    0.2743406295776367, 0.283984899520874, 0.2520174980163574, 0.21714305877685547,
    0.29296422004699707, 0.2083592414855957, 0.2681419849395752, 0.2597661018371582,
    0.2888021469116211, 0.26392030715942383, 0.20582938194274902, 0.3045811653137207,
    0.252197265625, 0.22195982933044434, 0.23456835746765137, 0.34484124183654785,
    0.21428656578063965, 0.28137755393981934, 0.24060916900634766, 0.23997235298156738,
    0.26070499420166016, 0.1937413215637207, 0.2733421325683594, 0.18274998664855957,
    0.26009273529052734, 0.31507229804992676, 0.2316582202911377, 0.22499656677246094,
    0.27273011207580566, 0.26110076904296875, 0.21703338623046875, 0.22130560874938965,
    0.264096736907959, 0.2787325382232666, 0.24606657028198242, 0.25850868225097656,
    0.215071439743042, 0.24307608604431152, 0.19768691062927246
])

print(f"Mean: {times.mean():0.6f} s")
print(f"Std: {times.std():0.6f} s")
print(f'min: {times.min():0.6f} s')
print(f'max: {times.max():0.6f} s')
# Out:
# Mean: 0.252726 s
# Std: 0.034529 s
# min: 0.182750 s
# max: 0.344841 s
